# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import time
from datetime import datetime
import requests
from config import weather_api_key
from config import g_key
import gmaps
import os

# %%
gmaps.configure(api_key = g_key)

# %%
city_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=72b28cc68627d225c33638cf69b4e45e

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 760

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1 
        time.sleep(60)

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        
        # Parse the JSON and retrieve data.
        city_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key \
        + '&q=' + city
        city_weather = requests.get(city_url).json()
       
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                         "Weather Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

#Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bengkulu
# Processing Record 2 of Set 1 | abu road
# Processing Record 3 of Set 1 | narsaq
# Processing Record 4 of Set 1 | lavrentiya
# Processing Record 5 of Set 1 | banda aceh
# Processing Record 6 of Set 1 | mocuba
# Processing Record 7 of Set 1 | manono
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | san carlos de bariloche
# Processing Record 10 of Set 1 | adrar
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 1 | puerto ayora
# Processing Record 14 of Set 1 | cherskiy
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | sawakin
# Processing Record 17 of Set 1 | hengshan
# Processing Record 18 of Set 1 | yining
# Processing Record 19 of Set 1 | salvador
# Processing Record 20 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 1 | areosa
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | nanortalik
# Processing Record 24 of Set 1 | lisakovsk
# Processing Record 25 of Set 1 | airai
# Processing Record 26 of Set 1 | bontang
# Processing Record 27 of Set 1 | hualmay
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | saldanha
# Processing Record 30 of Set 1 | strezhevoy
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | taiobeiras
# Processing Record 33 of Set 1 | chuy
# Processing Record 34 of Set 1 | khatanga
# Processing Record 35 of Set 1 | hilo
# Processing Record 36 of Set 1 | eidsvag
# Processing Record 37 of Set 1 | kahului
# Processing Record 38 of Set 1 | minab
# Processing Record 39 of Set 1 | faya
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | mazatlan
# Processing Record 42 of Set 1 | codrington
# Processing Record 43 of Set 1 | bambous virieux
# Processing Record 44 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 1 | havoysund
# Processing Record 46 of Set 1 | new norfolk
# Processing Record 47 of Set 1 | east london
# Processing Record 48 of Set 1 | saskylakh
# Processing Record 49 of Set 1 | santa clara
# Processing Record 50 of Set 1 | avarua
# Processing Record 1 of Set 2 | port elizabeth
# Processing Record 2 of Set 2 | rikitea
# Processing Record 3 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 2 | mar del plata
# Processing Record 5 of Set 2 | norman wells
# Processing Record 6 of Set 2 | qaanaaq
# Processing Record 7 of Set 2 | magdagachi
# Processing Record 8 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 2 | carnarvon
# Processing Record 10 of Set 2 | palu
# Processing Record 11 of Set 2 | bluff
# Processing Record 12 of Set 2 | cape town
# Processing Record 13 of Set 2 | ye
# City not found. Skipping...
# Processing Record 14 of Set 2 | hofn
# Processing Record 15 of Set 2 | shimoda
# Processing Record 16 of Set 2 | kirakira
# Processing Record 17 of Set 2 | mahebourg
# Processing Record 18 of Set 2 | baruun-urt
# Processing Record 19 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 2 | malur
# Processing Record 21 of Set 2 | jamestown
# Processing Record 22 of Set 2 | betong
# Processing Record 23 of Set 2 | champerico
# Processing Record 24 of Set 2 | along
# Processing Record 25 of Set 2 | mbaiki
# Processing Record 26 of Set 2 | pevek
# Processing Record 27 of Set 2 | kapaa
# Processing Record 28 of Set 2 | temaraia
# City not found. Skipping...
# Processing Record 29 of Set 2 | butaritari
# Processing Record 30 of Set 2 | virginia beach
# Processing Record 31 of Set 2 | kaoma
# Processing Record 32 of Set 2 | ca mau
# Processing Record 33 of Set 2 | kavieng
# Processing Record 34 of Set 2 | torbay
# Processing Record 35 of Set 2 | arraial do cabo
# Processing Record 36 of Set 2 | ngorongoro
# Processing Record 37 of Set 2 | nelson bay
# Processing Record 38 of Set 2 | pundaguitan
# Processing Record 39 of Set 2 | sobolevo
# Processing Record 40 of Set 2 | hobart
# Processing Record 41 of Set 2 | souillac
# Processing Record 42 of Set 2 | socorro
# Processing Record 43 of Set 2 | ribeira grande
# Processing Record 44 of Set 2 | cabo san lucas
# Processing Record 45 of Set 2 | xadani
# City not found. Skipping...
# Processing Record 46 of Set 2 | castro
# Processing Record 47 of Set 2 | kilindoni
# Processing Record 48 of Set 2 | pokhara
# Processing Record 49 of Set 2 | bay roberts
# Processing Record 50 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 1 of Set 3 | saint-philippe
# Processing Record 2 of Set 3 | krasnaya gorbatka
# Processing Record 3 of Set 3 | annau
# Processing Record 4 of Set 3 | broken hill
# Processing Record 5 of Set 3 | albania
# Processing Record 6 of Set 3 | port alfred
# Processing Record 7 of Set 3 | thompson
# Processing Record 8 of Set 3 | cortez
# Processing Record 9 of Set 3 | los llanos de aridane
# Processing Record 10 of Set 3 | kieta
# Processing Record 11 of Set 3 | atuona
# Processing Record 12 of Set 3 | baijiantan
# Processing Record 13 of Set 3 | tabuk
# Processing Record 14 of Set 3 | udachnyy
# Processing Record 15 of Set 3 | barrow
# Processing Record 16 of Set 3 | te anau
# Processing Record 17 of Set 3 | simav
# Processing Record 18 of Set 3 | marawi
# Processing Record 19 of Set 3 | kodinsk
# Processing Record 20 of Set 3 | tuatapere
# Processing Record 21 of Set 3 | chokurdakh
# Processing Record 22 of Set 3 | iquique
# Processing Record 23 of Set 3 | kaeo
# Processing Record 24 of Set 3 | srednekolymsk
# Processing Record 25 of Set 3 | tesalia
# Processing Record 26 of Set 3 | bujumbura
# Processing Record 27 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 28 of Set 3 | ixcatepec
# Processing Record 29 of Set 3 | mount gambier
# Processing Record 30 of Set 3 | gannan
# Processing Record 31 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 3 | puri
# Processing Record 34 of Set 3 | broome
# Processing Record 35 of Set 3 | sibolga
# Processing Record 36 of Set 3 | slave lake
# Processing Record 37 of Set 3 | viedma
# Processing Record 38 of Set 3 | karamay
# City not found. Skipping...
# Processing Record 39 of Set 3 | goundam
# Processing Record 40 of Set 3 | provideniya
# Processing Record 41 of Set 3 | comonfort
# Processing Record 42 of Set 3 | sillamae
# Processing Record 43 of Set 3 | sao felix do xingu
# Processing Record 44 of Set 3 | nikolskoye
# Processing Record 45 of Set 3 | tasiilaq
# Processing Record 46 of Set 3 | moose factory
# Processing Record 47 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 3 | baghmara
# Processing Record 49 of Set 3 | tessalit
# Processing Record 50 of Set 3 | claremore
# Processing Record 1 of Set 4 | vaini
# Processing Record 2 of Set 4 | isangel
# Processing Record 3 of Set 4 | livingston
# Processing Record 4 of Set 4 | bulalacao
# Processing Record 5 of Set 4 | cockburn town
# Processing Record 6 of Set 4 | georgetown
# Processing Record 7 of Set 4 | anadyr
# Processing Record 8 of Set 4 | salym
# Processing Record 9 of Set 4 | hithadhoo
# Processing Record 10 of Set 4 | port lincoln
# Processing Record 11 of Set 4 | krasnoselkup
# Processing Record 12 of Set 4 | aklavik
# Processing Record 13 of Set 4 | esperance
# Processing Record 14 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 4 | lewistown
# Processing Record 16 of Set 4 | north bend
# Processing Record 17 of Set 4 | dunedin
# Processing Record 18 of Set 4 | bethel
# Processing Record 19 of Set 4 | valparaiso
# Processing Record 20 of Set 4 | salinas
# Processing Record 21 of Set 4 | jojoima
# Processing Record 22 of Set 4 | port hardy
# Processing Record 23 of Set 4 | richards bay
# Processing Record 24 of Set 4 | yaan
# Processing Record 25 of Set 4 | upernavik
# Processing Record 26 of Set 4 | berdyaush
# Processing Record 27 of Set 4 | naron
# Processing Record 28 of Set 4 | beyneu
# Processing Record 29 of Set 4 | taunggyi
# Processing Record 30 of Set 4 | dali
# Processing Record 31 of Set 4 | missoula
# Processing Record 32 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 4 | nakhon phanom
# Processing Record 34 of Set 4 | tatarka
# Processing Record 35 of Set 4 | huayang
# Processing Record 36 of Set 4 | bredasdorp
# Processing Record 37 of Set 4 | vuktyl
# Processing Record 38 of Set 4 | boyuibe
# Processing Record 39 of Set 4 | mount isa
# Processing Record 40 of Set 4 | bayan
# Processing Record 41 of Set 4 | bam
# Processing Record 42 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 43 of Set 4 | port said
# Processing Record 44 of Set 4 | molteno
# Processing Record 45 of Set 4 | yerbogachen
# Processing Record 46 of Set 4 | trincomalee
# Processing Record 47 of Set 4 | farafangana
# Processing Record 48 of Set 4 | pisco
# Processing Record 49 of Set 4 | comodoro rivadavia
# Processing Record 50 of Set 4 | dalianwan
# Processing Record 1 of Set 5 | victoria
# Processing Record 2 of Set 5 | teguise
# Processing Record 3 of Set 5 | chabua
# Processing Record 4 of Set 5 | namibe
# Processing Record 5 of Set 5 | salinopolis
# Processing Record 6 of Set 5 | teya
# Processing Record 7 of Set 5 | shingu
# Processing Record 8 of Set 5 | vestmannaeyjar
# Processing Record 9 of Set 5 | sept-iles
# Processing Record 10 of Set 5 | betzdorf
# Processing Record 11 of Set 5 | westport
# Processing Record 12 of Set 5 | yellowknife
# Processing Record 13 of Set 5 | pitimbu
# Processing Record 14 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 5 | ahipara
# Processing Record 16 of Set 5 | moba
# Processing Record 17 of Set 5 | svobodnyy
# Processing Record 18 of Set 5 | hovd
# Processing Record 19 of Set 5 | nanning
# Processing Record 20 of Set 5 | mahmudia
# Processing Record 21 of Set 5 | roald
# Processing Record 22 of Set 5 | lazaro cardenas
# Processing Record 23 of Set 5 | algiers
# Processing Record 24 of Set 5 | pachino
# Processing Record 25 of Set 5 | mergui
# City not found. Skipping...
# Processing Record 26 of Set 5 | mogadishu
# Processing Record 27 of Set 5 | catuday
# Processing Record 28 of Set 5 | tazovskiy
# Processing Record 29 of Set 5 | mahibadhoo
# Processing Record 30 of Set 5 | auki
# Processing Record 31 of Set 5 | santa fe
# Processing Record 32 of Set 5 | vila velha
# Processing Record 33 of Set 5 | koumac
# Processing Record 34 of Set 5 | laguna
# Processing Record 35 of Set 5 | babstovo
# Processing Record 36 of Set 5 | montepuez
# Processing Record 37 of Set 5 | coquimbo
# Processing Record 38 of Set 5 | makakilo city
# Processing Record 39 of Set 5 | iqaluit
# Processing Record 40 of Set 5 | salalah
# Processing Record 41 of Set 5 | touros
# Processing Record 42 of Set 5 | barrhead
# Processing Record 43 of Set 5 | dikson
# Processing Record 44 of Set 5 | bonavista
# Processing Record 45 of Set 5 | kenai
# Processing Record 46 of Set 5 | fuerte olimpo
# Processing Record 47 of Set 5 | horn lake
# Processing Record 48 of Set 5 | kamenskiy
# Processing Record 49 of Set 5 | baherden
# Processing Record 50 of Set 5 | chalmette
# Processing Record 1 of Set 6 | vardo
# Processing Record 2 of Set 6 | kisangani
# Processing Record 3 of Set 6 | camacha
# Processing Record 4 of Set 6 | uryupinsk
# Processing Record 5 of Set 6 | sturgis
# Processing Record 6 of Set 6 | leghorn
# City not found. Skipping...
# Processing Record 7 of Set 6 | pasighat
# Processing Record 8 of Set 6 | emba
# Processing Record 9 of Set 6 | nizip
# Processing Record 10 of Set 6 | san roque
# Processing Record 11 of Set 6 | petersburg
# Processing Record 12 of Set 6 | sarangani
# Processing Record 13 of Set 6 | namatanai
# Processing Record 14 of Set 6 | wajir
# Processing Record 15 of Set 6 | vila franca do campo
# Processing Record 16 of Set 6 | lebu
# Processing Record 17 of Set 6 | tuktoyaktuk
# Processing Record 18 of Set 6 | balkanabat
# Processing Record 19 of Set 6 | ridgecrest
# Processing Record 20 of Set 6 | dumingag
# Processing Record 21 of Set 6 | laiyang
# Processing Record 22 of Set 6 | klaksvik
# Processing Record 23 of Set 6 | batagay
# Processing Record 24 of Set 6 | doha
# Processing Record 25 of Set 6 | brasilia de minas
# Processing Record 26 of Set 6 | katsuura
# Processing Record 27 of Set 6 | vanimo
# Processing Record 28 of Set 6 | solovetskiy
# City not found. Skipping...
# Processing Record 29 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 30 of Set 6 | pascagoula
# Processing Record 31 of Set 6 | baffa
# Processing Record 32 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 6 | axim
# Processing Record 34 of Set 6 | marivan
# Processing Record 35 of Set 6 | kavaratti
# Processing Record 36 of Set 6 | tautira
# Processing Record 37 of Set 6 | diego de almagro
# Processing Record 38 of Set 6 | welkom
# Processing Record 39 of Set 6 | saurimo
# Processing Record 40 of Set 6 | elat
# Processing Record 41 of Set 6 | amherstburg
# Processing Record 42 of Set 6 | siguiri
# Processing Record 43 of Set 6 | inverell
# Processing Record 44 of Set 6 | gazli
# Processing Record 45 of Set 6 | rio gallegos
# Processing Record 46 of Set 6 | demirci
# Processing Record 47 of Set 6 | mapiri
# Processing Record 48 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 49 of Set 6 | korla
# Processing Record 50 of Set 6 | mattawa
# Processing Record 1 of Set 7 | avera
# Processing Record 2 of Set 7 | sitka
# Processing Record 3 of Set 7 | ranong
# Processing Record 4 of Set 7 | leningradskiy
# Processing Record 5 of Set 7 | port-gentil
# Processing Record 6 of Set 7 | savasleyka
# Processing Record 7 of Set 7 | coihaique
# Processing Record 8 of Set 7 | villamontes
# Processing Record 9 of Set 7 | moerai
# Processing Record 10 of Set 7 | san cristobal
# Processing Record 11 of Set 7 | astana
# Processing Record 12 of Set 7 | mahanje
# Processing Record 13 of Set 7 | kaitangata
# Processing Record 14 of Set 7 | cienfuegos
# Processing Record 15 of Set 7 | juneau
# Processing Record 16 of Set 7 | cidreira
# Processing Record 17 of Set 7 | sao filipe
# Processing Record 18 of Set 7 | ostrovnoy
# Processing Record 19 of Set 7 | ilhabela
# Processing Record 20 of Set 7 | paamiut
# Processing Record 21 of Set 7 | el cobre
# Processing Record 22 of Set 7 | ponta do sol
# Processing Record 23 of Set 7 | lompoc
# Processing Record 24 of Set 7 | waitati
# Processing Record 25 of Set 7 | rawson
# Processing Record 26 of Set 7 | ituni
# City not found. Skipping...
# Processing Record 27 of Set 7 | kodiak
# Processing Record 28 of Set 7 | bilibino
# Processing Record 29 of Set 7 | sao joao da barra
# Processing Record 30 of Set 7 | shenjiamen
# Processing Record 31 of Set 7 | candelaria
# Processing Record 32 of Set 7 | aguimes
# Processing Record 33 of Set 7 | zhuhai
# Processing Record 34 of Set 7 | xingtai
# Processing Record 35 of Set 7 | bubaque
# Processing Record 36 of Set 7 | linhares
# Processing Record 37 of Set 7 | nyurba
# Processing Record 38 of Set 7 | awbari
# Processing Record 39 of Set 7 | yar-sale
# Processing Record 40 of Set 7 | morlaix
# Processing Record 41 of Set 7 | zyryanka
# Processing Record 42 of Set 7 | akureyri
# Processing Record 43 of Set 7 | berlevag
# Processing Record 44 of Set 7 | tevriz
# Processing Record 45 of Set 7 | toucheng
# Processing Record 46 of Set 7 | marshalltown
# Processing Record 47 of Set 7 | ulagan
# Processing Record 48 of Set 7 | manado
# Processing Record 49 of Set 7 | ugoofaaru
# Processing Record 50 of Set 7 | nioro
# Processing Record 1 of Set 8 | sarankhola
# Processing Record 2 of Set 8 | loikaw
# Processing Record 3 of Set 8 | yong peng
# Processing Record 4 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 5 of Set 8 | capitao poco
# Processing Record 6 of Set 8 | longyearbyen
# Processing Record 7 of Set 8 | orthez
# Processing Record 8 of Set 8 | hami
# Processing Record 9 of Set 8 | khandyga
# Processing Record 10 of Set 8 | mayo
# Processing Record 11 of Set 8 | buala
# Processing Record 12 of Set 8 | clyde river
# Processing Record 13 of Set 8 | phun phin
# City not found. Skipping...
# Processing Record 14 of Set 8 | yulara
# Processing Record 15 of Set 8 | haines junction
# Processing Record 16 of Set 8 | bahar
# Processing Record 17 of Set 8 | severo-kurilsk
# Processing Record 18 of Set 8 | itanhem
# Processing Record 19 of Set 8 | lohja
# Processing Record 20 of Set 8 | deputatskiy
# Processing Record 21 of Set 8 | lorengau
# Processing Record 22 of Set 8 | mezen
# Processing Record 23 of Set 8 | lithakia
# Processing Record 24 of Set 8 | petatlan
# Processing Record 25 of Set 8 | trapani
# Processing Record 26 of Set 8 | horta
# Processing Record 27 of Set 8 | prince rupert
# Processing Record 28 of Set 8 | erdaojiang
# Processing Record 29 of Set 8 | nancha
# Processing Record 30 of Set 8 | kovvur
# Processing Record 31 of Set 8 | serta
# Processing Record 32 of Set 8 | chapais
# Processing Record 33 of Set 8 | sorland
# Processing Record 34 of Set 8 | khanpur
# Processing Record 35 of Set 8 | bathsheba
# Processing Record 36 of Set 8 | santa lucia
# Processing Record 37 of Set 8 | saint-augustin
# Processing Record 38 of Set 8 | vung tau
# Processing Record 39 of Set 8 | matameye
# City not found. Skipping...
# Processing Record 40 of Set 8 | kapoeta
# Processing Record 41 of Set 8 | ayan
# Processing Record 42 of Set 8 | priladozhskiy
# Processing Record 43 of Set 8 | guerrero negro
# Processing Record 44 of Set 8 | amuntai
# Processing Record 45 of Set 8 | talnakh
# Processing Record 46 of Set 8 | orlik
# Processing Record 47 of Set 8 | floro
# Processing Record 48 of Set 8 | vylgort
# City not found. Skipping...
# Processing Record 49 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 8 | ancud
# Processing Record 1 of Set 9 | biak
# Processing Record 2 of Set 9 | bacolod
# Processing Record 3 of Set 9 | sabang
# Processing Record 4 of Set 9 | northam
# Processing Record 5 of Set 9 | terrell
# Processing Record 6 of Set 9 | kurilsk
# Processing Record 7 of Set 9 | vao
# Processing Record 8 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 9 | nyaunglebin
# Processing Record 10 of Set 9 | varnavino
# Processing Record 11 of Set 9 | bhopal
# Processing Record 12 of Set 9 | yatou
# Processing Record 13 of Set 9 | moron
# Processing Record 14 of Set 9 | gat
# Processing Record 15 of Set 9 | tiksi
# Processing Record 16 of Set 9 | kudymkar
# Processing Record 17 of Set 9 | asyut
# Processing Record 18 of Set 9 | atka
# City not found. Skipping...
# Processing Record 19 of Set 9 | progreso
# Processing Record 20 of Set 9 | rybinsk
# Processing Record 21 of Set 9 | yunyang
# Processing Record 22 of Set 9 | constitucion
# Processing Record 23 of Set 9 | klichka
# Processing Record 24 of Set 9 | tera
# Processing Record 25 of Set 9 | porto novo
# Processing Record 26 of Set 9 | faanui
# Processing Record 27 of Set 9 | sinnamary
# Processing Record 28 of Set 9 | cuencame
# Processing Record 29 of Set 9 | alyangula
# Processing Record 30 of Set 9 | buka
# Processing Record 31 of Set 9 | capaccio
# Processing Record 32 of Set 9 | valera
# Processing Record 33 of Set 9 | mareeba
# Processing Record 34 of Set 9 | igdir
# Processing Record 35 of Set 9 | bandarbeyla
# Processing Record 36 of Set 9 | verkhnetulomskiy
# Processing Record 37 of Set 9 | lasa
# Processing Record 38 of Set 9 | lobatse
# Processing Record 39 of Set 9 | filingue
# Processing Record 40 of Set 9 | mollendo
# Processing Record 41 of Set 9 | yima
# Processing Record 42 of Set 9 | breves
# Processing Record 43 of Set 9 | abbeville
# Processing Record 44 of Set 9 | aksu
# Processing Record 45 of Set 9 | shiyan
# Processing Record 46 of Set 9 | zhaotong
# Processing Record 47 of Set 9 | kimbe
# Processing Record 48 of Set 9 | pedreiras
# Processing Record 49 of Set 9 | kozhva
# Processing Record 50 of Set 9 | pangnirtung
# Processing Record 1 of Set 10 | takoradi
# Processing Record 2 of Set 10 | jijiga
# Processing Record 3 of Set 10 | yueyang
# Processing Record 4 of Set 10 | godda
# Processing Record 5 of Set 10 | zeya
# Processing Record 6 of Set 10 | tocopilla
# Processing Record 7 of Set 10 | chato
# Processing Record 8 of Set 10 | mabaruma
# Processing Record 9 of Set 10 | port blair
# Processing Record 10 of Set 10 | malakal
# Processing Record 11 of Set 10 | buta
# Processing Record 12 of Set 10 | mayumba
# Processing Record 13 of Set 10 | kutum
# Processing Record 14 of Set 10 | guanica
# Processing Record 15 of Set 10 | thomasville
# Processing Record 16 of Set 10 | susanville
# Processing Record 17 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 18 of Set 10 | kulhudhuffushi
# Processing Record 19 of Set 10 | college
# Processing Record 20 of Set 10 | kudahuvadhoo
# Processing Record 21 of Set 10 | port hedland
# Processing Record 22 of Set 10 | linxia
# Processing Record 23 of Set 10 | matir
# City not found. Skipping...
# Processing Record 24 of Set 10 | beterou
# Processing Record 25 of Set 10 | ponta delgada
# Processing Record 26 of Set 10 | matay
# Processing Record 27 of Set 10 | dothan
# Processing Record 28 of Set 10 | pacific grove
# Processing Record 29 of Set 10 | kamen-rybolov
# Processing Record 30 of Set 10 | skelleftea
# Processing Record 31 of Set 10 | aden
# Processing Record 32 of Set 10 | coahuayana
# Processing Record 33 of Set 10 | pangody
# Processing Record 34 of Set 10 | bassano
# Processing Record 35 of Set 10 | athens
# Processing Record 36 of Set 10 | saint george
# Processing Record 37 of Set 10 | grand gaube
# Processing Record 38 of Set 10 | la ronge
# Processing Record 39 of Set 10 | eureka
# Processing Record 40 of Set 10 | asau
# Processing Record 41 of Set 10 | rawah
# Processing Record 42 of Set 10 | aswan
# Processing Record 43 of Set 10 | pindobacu
# Processing Record 44 of Set 10 | acapulco
# Processing Record 45 of Set 10 | manzil salim
# Processing Record 46 of Set 10 | lahat
# Processing Record 47 of Set 10 | porto nacional
# Processing Record 48 of Set 10 | nunchia
# Processing Record 49 of Set 10 | fort nelson
# Processing Record 50 of Set 10 | meulaboh
# Processing Record 1 of Set 11 | fairview
# Processing Record 2 of Set 11 | maldonado
# Processing Record 3 of Set 11 | yumen
# Processing Record 4 of Set 11 | sistranda
# Processing Record 5 of Set 11 | agogo
# Processing Record 6 of Set 11 | cockburn harbour
# City not found. Skipping...
# Processing Record 7 of Set 11 | dong hoi
# Processing Record 8 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 9 of Set 11 | alofi
# Processing Record 10 of Set 11 | scarborough
# Processing Record 11 of Set 11 | dalby
# Processing Record 12 of Set 11 | sioux lookout
# Processing Record 13 of Set 11 | palaiokhora
# City not found. Skipping...
# Processing Record 14 of Set 11 | kassala
# Processing Record 15 of Set 11 | gizo
# Processing Record 16 of Set 11 | saint-leu
# Processing Record 17 of Set 11 | ghogha
# Processing Record 18 of Set 11 | russell
# Processing Record 19 of Set 11 | itarema
# Processing Record 20 of Set 11 | jiaohe
# Processing Record 21 of Set 11 | conway
# Processing Record 22 of Set 11 | lata
# Processing Record 23 of Set 11 | elizabeth city
# Processing Record 24 of Set 11 | canoa
# Processing Record 25 of Set 11 | malanje
# Processing Record 26 of Set 11 | dindori
# Processing Record 27 of Set 11 | arlit
# Processing Record 28 of Set 11 | reinosa
# Processing Record 29 of Set 11 | hasaki
# Processing Record 30 of Set 11 | kuruksay
# City not found. Skipping...
# Processing Record 31 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 32 of Set 11 | geraldton
# Processing Record 33 of Set 11 | staroye drozhzhanoye
# Processing Record 34 of Set 11 | tarko-sale
# Processing Record 35 of Set 11 | hamilton
# Processing Record 36 of Set 11 | katobu
# Processing Record 37 of Set 11 | tsagan aman
# Processing Record 38 of Set 11 | mwinilunga
# Processing Record 39 of Set 11 | birao
# Processing Record 40 of Set 11 | urumqi
# Processing Record 41 of Set 11 | khambhaliya
# Processing Record 42 of Set 11 | caravelas
# Processing Record 43 of Set 11 | tonj
# Processing Record 44 of Set 11 | liverpool
# Processing Record 45 of Set 11 | fortuna
# Processing Record 46 of Set 11 | caska
# Processing Record 47 of Set 11 | celestun
# Processing Record 48 of Set 11 | esna
# Processing Record 49 of Set 11 | metz
# Processing Record 50 of Set 11 | gandorhun
# Processing Record 1 of Set 12 | muros
# Processing Record 2 of Set 12 | superior
# Processing Record 3 of Set 12 | bibiani
# Processing Record 4 of Set 12 | lagoa
# Processing Record 5 of Set 12 | clevelandia
# Processing Record 6 of Set 12 | batagay-alyta
# Processing Record 7 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 8 of Set 12 | argelia
# Processing Record 9 of Set 12 | olafsvik
# Processing Record 10 of Set 12 | sunbury
# Processing Record 11 of Set 12 | lesnoy
# Processing Record 12 of Set 12 | birigui
# Processing Record 13 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 14 of Set 12 | crab hill
# City not found. Skipping...
# Processing Record 15 of Set 12 | najran
# Processing Record 16 of Set 12 | moyale
# Processing Record 17 of Set 12 | vila
# Processing Record 18 of Set 12 | inta
# Processing Record 19 of Set 12 | lukulu
# Processing Record 20 of Set 12 | san quintin
# Processing Record 21 of Set 12 | luderitz
# Processing Record 22 of Set 12 | saint anthony
# Processing Record 23 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 12 | dingle
# Processing Record 25 of Set 12 | yabrud
# Processing Record 26 of Set 12 | mailsi
# Processing Record 27 of Set 12 | luau
# Processing Record 28 of Set 12 | cradock
# Processing Record 29 of Set 12 | bollnas
# Processing Record 30 of Set 12 | huarmey
# Processing Record 31 of Set 12 | jadu
# Processing Record 32 of Set 12 | port macquarie
# Processing Record 33 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 34 of Set 12 | ust-kulom
# Processing Record 35 of Set 12 | fairbanks
# Processing Record 36 of Set 12 | grindavik
# Processing Record 37 of Set 12 | plouzane
# Processing Record 38 of Set 12 | jumla
# Processing Record 39 of Set 12 | cotonou
# Processing Record 40 of Set 12 | labuhan
# Processing Record 41 of Set 12 | marsh harbour
# Processing Record 42 of Set 12 | estepa
# Processing Record 43 of Set 12 | port augusta
# Processing Record 44 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 12 | wanning
# Processing Record 46 of Set 12 | dalvik
# Processing Record 47 of Set 12 | maraa
# Processing Record 48 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 49 of Set 12 | tallmadge
# Processing Record 50 of Set 12 | muroto
# Processing Record 1 of Set 13 | bridgetown
# Processing Record 2 of Set 13 | kurkino
# Processing Record 3 of Set 13 | zambezi
# Processing Record 4 of Set 13 | douentza
# Processing Record 5 of Set 13 | shubarkuduk
# Processing Record 6 of Set 13 | sinkat
# City not found. Skipping...
# Processing Record 7 of Set 13 | zolotinka
# City not found. Skipping...
# Processing Record 8 of Set 13 | mehamn
# Processing Record 9 of Set 13 | sampues
# Processing Record 10 of Set 13 | negombo
# Processing Record 11 of Set 13 | yenangyaung
# Processing Record 12 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 13 of Set 13 | qaqortoq
# Processing Record 14 of Set 13 | nakano
# Processing Record 15 of Set 13 | zhigansk
# Processing Record 16 of Set 13 | karratha
# Processing Record 17 of Set 13 | cepu
# Processing Record 18 of Set 13 | liepaja
# Processing Record 19 of Set 13 | ylivieska
# Processing Record 20 of Set 13 | bexhill
# Processing Record 21 of Set 13 | naze
# Processing Record 22 of Set 13 | mwanza
# Processing Record 23 of Set 13 | aloja
# Processing Record 24 of Set 13 | saint-georges
# Processing Record 25 of Set 13 | jieshi
# Processing Record 26 of Set 13 | gidole
# Processing Record 27 of Set 13 | basoko
# Processing Record 28 of Set 13 | mansa
# Processing Record 29 of Set 13 | garm
# City not found. Skipping...
# Processing Record 30 of Set 13 | burla
# Processing Record 31 of Set 13 | iralaya
# Processing Record 32 of Set 13 | la ciotat
# Processing Record 33 of Set 13 | noumea
# Processing Record 34 of Set 13 | tilichiki
# Processing Record 35 of Set 13 | yenagoa
# Processing Record 36 of Set 13 | nokaneng
# Processing Record 37 of Set 13 | agirish
# Processing Record 38 of Set 13 | monrovia
# Processing Record 39 of Set 13 | lehigh acres
# Processing Record 40 of Set 13 | jimenez
# Processing Record 41 of Set 13 | qui nhon
# Processing Record 42 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 13 | pandharpur
# Processing Record 44 of Set 13 | zhezkazgan
# Processing Record 45 of Set 13 | flin flon
# Processing Record 46 of Set 13 | buarcos
# Processing Record 47 of Set 13 | gazanjyk
# Processing Record 48 of Set 13 | kushima
# Processing Record 49 of Set 13 | perth
# Processing Record 50 of Set 13 | florianopolis
# Processing Record 1 of Set 14 | ulaanbaatar
# Processing Record 2 of Set 14 | sangar
# Processing Record 3 of Set 14 | lima
# Processing Record 4 of Set 14 | huanren
# Processing Record 5 of Set 14 | sabha
# Processing Record 6 of Set 14 | elliot
# Processing Record 7 of Set 14 | kuito
# Processing Record 8 of Set 14 | raychikhinsk
# Processing Record 9 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 10 of Set 14 | havre-saint-pierre
# Processing Record 11 of Set 14 | kumbo
# Processing Record 12 of Set 14 | healdsburg
# Processing Record 13 of Set 14 | turinsk
# Processing Record 14 of Set 14 | muravlenko
# Processing Record 15 of Set 14 | leh
# Processing Record 16 of Set 14 | omsukchan
# Processing Record 17 of Set 14 | oriximina
# Processing Record 18 of Set 14 | nongstoin
# Processing Record 19 of Set 14 | willmar
# Processing Record 20 of Set 14 | dar es salaam
# Processing Record 21 of Set 14 | devonport
# Processing Record 22 of Set 14 | nicoya
# Processing Record 23 of Set 14 | teruel
# Processing Record 24 of Set 14 | turbat
# Processing Record 25 of Set 14 | komsomolskiy
# Processing Record 26 of Set 14 | muisne
# Processing Record 27 of Set 14 | gondanglegi
# Processing Record 28 of Set 14 | griffith
# Processing Record 29 of Set 14 | besikduzu
# Processing Record 30 of Set 14 | methuen
# Processing Record 31 of Set 14 | alexandria
# Processing Record 32 of Set 14 | tavagnacco
# Processing Record 33 of Set 14 | pemangkat
# Processing Record 34 of Set 14 | tadine
# Processing Record 35 of Set 14 | taltal
# Processing Record 36 of Set 14 | nueva loja
# Processing Record 37 of Set 14 | dubti
# Processing Record 38 of Set 14 | beringovskiy
# Processing Record 39 of Set 14 | bintulu
# Processing Record 40 of Set 14 | jibuti
# Processing Record 41 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 42 of Set 14 | lubbock
# Processing Record 43 of Set 14 | brenham
# Processing Record 44 of Set 14 | leshukonskoye
# Processing Record 45 of Set 14 | la asuncion
# Processing Record 46 of Set 14 | vereeniging
# Processing Record 47 of Set 14 | eirunepe
# Processing Record 48 of Set 14 | tual
# Processing Record 49 of Set 14 | cairns
# Processing Record 50 of Set 14 | tahoua
# Processing Record 1 of Set 15 | alcudia
# Processing Record 2 of Set 15 | houma
# Processing Record 3 of Set 15 | channel-port aux basques
# Processing Record 4 of Set 15 | evensk
# Processing Record 5 of Set 15 | paka
# Processing Record 6 of Set 15 | fort-shevchenko
# Processing Record 7 of Set 15 | cleethorpes
# Processing Record 8 of Set 15 | monroe
# Processing Record 9 of Set 15 | ahuimanu
# Processing Record 10 of Set 15 | ilulissat
# Processing Record 11 of Set 15 | kruisfontein
# Processing Record 12 of Set 15 | itacare
# Processing Record 13 of Set 15 | kununurra
# Processing Record 14 of Set 15 | iskateley
# Processing Record 15 of Set 15 | olinda
# Processing Record 16 of Set 15 | walvis bay
# Processing Record 17 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 15 | tura
# Processing Record 19 of Set 15 | hambantota
# Processing Record 20 of Set 15 | tuy hoa
# Processing Record 21 of Set 15 | hidalgotitlan
# Processing Record 22 of Set 15 | kiunga
# Processing Record 23 of Set 15 | salina cruz
# Processing Record 24 of Set 15 | udhampur
# Processing Record 25 of Set 15 | nantucket
# Processing Record 26 of Set 15 | aasiaat
# Processing Record 27 of Set 15 | znamenskoye
# Processing Record 28 of Set 15 | chicama
# Processing Record 29 of Set 15 | mouzakion
# City not found. Skipping...
# Processing Record 30 of Set 15 | xianyang
# Processing Record 31 of Set 15 | gubkinskiy
# Processing Record 32 of Set 15 | miyako
# Processing Record 33 of Set 15 | harper
# Processing Record 34 of Set 15 | puerto quijarro
# Processing Record 35 of Set 15 | sao jose da coroa grande
# Processing Record 36 of Set 15 | flinders
# Processing Record 37 of Set 15 | gornopravdinsk
# Processing Record 38 of Set 15 | adelanto
# Processing Record 39 of Set 15 | taoudenni
# Processing Record 40 of Set 15 | pontiac
# Processing Record 41 of Set 15 | hongjiang
# Processing Record 42 of Set 15 | fatikchhari
# City not found. Skipping...
# Processing Record 43 of Set 15 | nanchong
# Processing Record 44 of Set 15 | okhotsk
# Processing Record 45 of Set 15 | obo
# Processing Record 46 of Set 15 | novyy urengoy
# Processing Record 47 of Set 15 | safaga
# Processing Record 48 of Set 15 | zafarabad
# Processing Record 49 of Set 15 | buchanan
# Processing Record 50 of Set 15 | kemijarvi
# Processing Record 1 of Set 16 | vostok
# Processing Record 2 of Set 16 | santa isabel do rio negro
# Processing Record 3 of Set 16 | saint-pierre
# Processing Record 4 of Set 16 | aneho
# Processing Record 5 of Set 16 | gladstone
# Processing Record 6 of Set 16 | shaunavon
# Processing Record 7 of Set 16 | maryborough
# Processing Record 8 of Set 16 | amancio
# City not found. Skipping...
# Processing Record 9 of Set 16 | puerto escondido
# Processing Record 10 of Set 16 | mvuma
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#city_data_to_load = 
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                       City Country      Lat       Lng  Max Temp  Humidity  \
# 0                 Bengkulu      ID  -3.8004  102.2655     76.24        85
# 1                 Abu Road      IN  24.4833   72.7833     61.36        50
# 2                   Narsaq      GL  60.9167  -46.0500      7.02        58
# 3               Lavrentiya      RU  65.5833 -171.0000    -12.64        93
# 4               Banda Aceh      ID   5.5577   95.3222     76.14        92
# 5                   Mocuba      MZ -16.8392   36.9856     72.70        96
# 6                   Manono      CD  -7.3000   27.4167     71.06        93
# 7                   Albany      US  42.6001  -73.9662     24.62        51
# 8  San Carlos De Bariloche      AR -41.1456  -71.3082     76.75        23
# 9                    Adrar      MR  20.5022  -10.0711     83.46         6
#
#    Cloudiness  Wind Speed Weather Description
# 0          98        6.67     overcast clouds
# 1           0        2.51           clear sky
# 2         100        3.06     overcast clouds
# 3           5        6.20           clear sky
# 4         100       11.63       moderate rain
# 5          32        4.76          light rain
# 6          99        4.09       moderate rain
# 7          16        3.00          few clouds
# 8           0        4.61           clear sky
# 9           0        8.79           clear sky

# %%
# Export data frame as CSV
output_data_file = 'WeatherPy_Database.csv'
city_data_df.to_csv(output_data_file,index_label='City_ID')
