# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 627

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(5)

    # Create endpoint URL with each city.
    city_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

#Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mahebourg
# Processing Record 2 of Set 1 | porto novo
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | bardiyah
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | wasilla
# Processing Record 8 of Set 1 | mar del plata
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | bambous virieux
# Processing Record 11 of Set 1 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 12 of Set 1 | castro
# Processing Record 13 of Set 1 | uray
# Processing Record 14 of Set 1 | jidong
# Processing Record 15 of Set 1 | touros
# Processing Record 16 of Set 1 | puerto ayora
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | sitka
# Processing Record 19 of Set 1 | lebu
# Processing Record 20 of Set 1 | araucaria
# Processing Record 21 of Set 1 | kaeo
# Processing Record 22 of Set 1 | chimbote
# Processing Record 23 of Set 1 | hofn
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | new norfolk
# Processing Record 28 of Set 1 | sao joao da barra
# Processing Record 29 of Set 1 | port blair
# Processing Record 30 of Set 1 | shar
# Processing Record 31 of Set 1 | east london
# Processing Record 32 of Set 1 | borama
# City not found. Skipping...
# Processing Record 33 of Set 1 | talnakh
# Processing Record 34 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 1 | vaini
# Processing Record 36 of Set 1 | komsomolskiy
# Processing Record 37 of Set 1 | khandyga
# Processing Record 38 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 1 | sechura
# Processing Record 40 of Set 1 | dromolaxia
# Processing Record 41 of Set 1 | dzilam gonzalez
# Processing Record 42 of Set 1 | north ridgeville
# Processing Record 43 of Set 1 | ribeira grande
# Processing Record 44 of Set 1 | ushuaia
# Processing Record 45 of Set 1 | provideniya
# Processing Record 46 of Set 1 | iqaluit
# Processing Record 47 of Set 1 | pontes e lacerda
# Processing Record 48 of Set 1 | gornopravdinsk
# Processing Record 49 of Set 1 | chuy
# Processing Record 50 of Set 1 | mount isa
# Processing Record 1 of Set 2 | arraial do cabo
# Processing Record 2 of Set 2 | paragominas
# Processing Record 3 of Set 2 | inverell
# Processing Record 4 of Set 2 | busselton
# Processing Record 5 of Set 2 | awbari
# Processing Record 6 of Set 2 | bluff
# Processing Record 7 of Set 2 | kodiak
# Processing Record 8 of Set 2 | muisne
# Processing Record 9 of Set 2 | kirakira
# Processing Record 10 of Set 2 | jamestown
# Processing Record 11 of Set 2 | bandar-e lengeh
# Processing Record 12 of Set 2 | barrow
# Processing Record 13 of Set 2 | pevek
# Processing Record 14 of Set 2 | port hardy
# Processing Record 15 of Set 2 | zhigansk
# Processing Record 16 of Set 2 | qaanaaq
# Processing Record 17 of Set 2 | richards bay
# Processing Record 18 of Set 2 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 19 of Set 2 | gurgan
# City not found. Skipping...
# Processing Record 20 of Set 2 | nago
# Processing Record 21 of Set 2 | sorland
# Processing Record 22 of Set 2 | mocambique
# City not found. Skipping...
# Processing Record 23 of Set 2 | ilulissat
# Processing Record 24 of Set 2 | bethel
# Processing Record 25 of Set 2 | sonoita
# Processing Record 26 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 2 | volot
# Processing Record 28 of Set 2 | luanda
# Processing Record 29 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 2 | salalah
# Processing Record 31 of Set 2 | hithadhoo
# Processing Record 32 of Set 2 | tuktoyaktuk
# Processing Record 33 of Set 2 | nautla
# Processing Record 34 of Set 2 | ixtapa
# Processing Record 35 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 2 | arvika
# Processing Record 37 of Set 2 | tiznit
# City not found. Skipping...
# Processing Record 38 of Set 2 | upernavik
# Processing Record 39 of Set 2 | praia da vitoria
# Processing Record 40 of Set 2 | srednekolymsk
# Processing Record 41 of Set 2 | ongandjera
# Processing Record 42 of Set 2 | esperance
# Processing Record 43 of Set 2 | nishihara
# Processing Record 44 of Set 2 | kifri
# Processing Record 45 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 46 of Set 2 | mount gambier
# Processing Record 47 of Set 2 | itarema
# Processing Record 48 of Set 2 | avarua
# Processing Record 49 of Set 2 | guerrero negro
# Processing Record 50 of Set 2 | cabo san lucas
# Processing Record 1 of Set 3 | mehamn
# Processing Record 2 of Set 3 | port alfred
# Processing Record 3 of Set 3 | caucaia
# Processing Record 4 of Set 3 | troyes
# Processing Record 5 of Set 3 | aklavik
# Processing Record 6 of Set 3 | honiara
# Processing Record 7 of Set 3 | buraydah
# Processing Record 8 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 9 of Set 3 | namibe
# Processing Record 10 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 11 of Set 3 | evensk
# Processing Record 12 of Set 3 | eureka
# Processing Record 13 of Set 3 | souillac
# Processing Record 14 of Set 3 | norman wells
# Processing Record 15 of Set 3 | manavalakurichi
# Processing Record 16 of Set 3 | faanui
# Processing Record 17 of Set 3 | brae
# Processing Record 18 of Set 3 | ninghai
# Processing Record 19 of Set 3 | boatlaname
# City not found. Skipping...
# Processing Record 20 of Set 3 | banda aceh
# Processing Record 21 of Set 3 | chokurdakh
# Processing Record 22 of Set 3 | cape town
# Processing Record 23 of Set 3 | saskylakh
# Processing Record 24 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 3 | komatipoort
# Processing Record 26 of Set 3 | meulaboh
# Processing Record 27 of Set 3 | sao filipe
# Processing Record 28 of Set 3 | hualmay
# Processing Record 29 of Set 3 | letlhakane
# Processing Record 30 of Set 3 | severo-kurilsk
# Processing Record 31 of Set 3 | cherskiy
# Processing Record 32 of Set 3 | manacapuru
# Processing Record 33 of Set 3 | tiksi
# Processing Record 34 of Set 3 | hamilton
# Processing Record 35 of Set 3 | izhma
# Processing Record 36 of Set 3 | margate
# Processing Record 37 of Set 3 | airai
# Processing Record 38 of Set 3 | san policarpo
# Processing Record 39 of Set 3 | lang suan
# Processing Record 40 of Set 3 | longyearbyen
# Processing Record 41 of Set 3 | hilo
# Processing Record 42 of Set 3 | saint george
# Processing Record 43 of Set 3 | toamasina
# Processing Record 44 of Set 3 | korla
# Processing Record 45 of Set 3 | san-pedro
# Processing Record 46 of Set 3 | ancud
# Processing Record 47 of Set 3 | yellowknife
# Processing Record 48 of Set 3 | san pedro del pinatar
# Processing Record 49 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 3 | marabba
# Processing Record 1 of Set 4 | atlantic beach
# Processing Record 2 of Set 4 | atkarsk
# Processing Record 3 of Set 4 | bredasdorp
# Processing Record 4 of Set 4 | moose factory
# Processing Record 5 of Set 4 | san cristobal
# Processing Record 6 of Set 4 | nikolskoye
# Processing Record 7 of Set 4 | kapaa
# Processing Record 8 of Set 4 | plyussa
# Processing Record 9 of Set 4 | kahului
# Processing Record 10 of Set 4 | oranjemund
# Processing Record 11 of Set 4 | khatanga
# Processing Record 12 of Set 4 | shimoda
# Processing Record 13 of Set 4 | clyde river
# Processing Record 14 of Set 4 | zbarazh
# Processing Record 15 of Set 4 | eidsvag
# Processing Record 16 of Set 4 | kruisfontein
# Processing Record 17 of Set 4 | kavieng
# Processing Record 18 of Set 4 | avera
# Processing Record 19 of Set 4 | pisco
# Processing Record 20 of Set 4 | muros
# Processing Record 21 of Set 4 | buchanan
# Processing Record 22 of Set 4 | kaitangata
# Processing Record 23 of Set 4 | hobart
# Processing Record 24 of Set 4 | nouakchott
# Processing Record 25 of Set 4 | melito di porto salvo
# Processing Record 26 of Set 4 | qom
# Processing Record 27 of Set 4 | bandarbeyla
# Processing Record 28 of Set 4 | khani
# Processing Record 29 of Set 4 | tasiilaq
# Processing Record 30 of Set 4 | mullaitivu
# City not found. Skipping...
# Processing Record 31 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 32 of Set 4 | husavik
# Processing Record 33 of Set 4 | tokuyama
# Processing Record 34 of Set 4 | hobyo
# Processing Record 35 of Set 4 | padang
# Processing Record 36 of Set 4 | kinablangan
# Processing Record 37 of Set 4 | sale
# Processing Record 38 of Set 4 | geraldton
# Processing Record 39 of Set 4 | vila franca do campo
# Processing Record 40 of Set 4 | maxixe
# Processing Record 41 of Set 4 | hambantota
# Processing Record 42 of Set 4 | havre-saint-pierre
# Processing Record 43 of Set 4 | nemuro
# Processing Record 44 of Set 4 | lompoc
# Processing Record 45 of Set 4 | veliki crljeni
# Processing Record 46 of Set 4 | marfino
# Processing Record 47 of Set 4 | ekhabi
# Processing Record 48 of Set 4 | santa maria
# Processing Record 49 of Set 4 | necochea
# Processing Record 50 of Set 4 | olafsvik
# Processing Record 1 of Set 5 | flagstaff
# Processing Record 2 of Set 5 | zyryanka
# Processing Record 3 of Set 5 | dikson
# Processing Record 4 of Set 5 | corumba
# Processing Record 5 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 6 of Set 5 | rivadavia
# Processing Record 7 of Set 5 | moranbah
# Processing Record 8 of Set 5 | sri aman
# Processing Record 9 of Set 5 | vestmannaeyjar
# Processing Record 10 of Set 5 | general roca
# Processing Record 11 of Set 5 | nome
# Processing Record 12 of Set 5 | punta arenas
# Processing Record 13 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 5 | vao
# Processing Record 17 of Set 5 | san miguel
# Processing Record 18 of Set 5 | belaya gora
# Processing Record 19 of Set 5 | crab hill
# City not found. Skipping...
# Processing Record 20 of Set 5 | comodoro rivadavia
# Processing Record 21 of Set 5 | pietersburg
# Processing Record 22 of Set 5 | palana
# Processing Record 23 of Set 5 | chumikan
# Processing Record 24 of Set 5 | zhezkazgan
# Processing Record 25 of Set 5 | waingapu
# Processing Record 26 of Set 5 | ternate
# Processing Record 27 of Set 5 | saint-joseph
# Processing Record 28 of Set 5 | roma
# Processing Record 29 of Set 5 | waiuku
# Processing Record 30 of Set 5 | russell
# Processing Record 31 of Set 5 | grindsted
# Processing Record 32 of Set 5 | pangnirtung
# Processing Record 33 of Set 5 | port lincoln
# Processing Record 34 of Set 5 | saint-philippe
# Processing Record 35 of Set 5 | ust-tsilma
# Processing Record 36 of Set 5 | la ronge
# Processing Record 37 of Set 5 | camacha
# Processing Record 38 of Set 5 | kalabo
# Processing Record 39 of Set 5 | north bend
# Processing Record 40 of Set 5 | shibetsu
# Processing Record 41 of Set 5 | deputatskiy
# Processing Record 42 of Set 5 | suda
# Processing Record 43 of Set 5 | kysyl-syr
# Processing Record 44 of Set 5 | fallon
# Processing Record 45 of Set 5 | santa vitoria do palmar
# Processing Record 46 of Set 5 | skjervoy
# Processing Record 47 of Set 5 | kilcormac
# Processing Record 48 of Set 5 | poum
# Processing Record 49 of Set 5 | ahipara
# Processing Record 50 of Set 5 | ponta do sol
# Processing Record 1 of Set 6 | thompson
# Processing Record 2 of Set 6 | channel-port aux basques
# Processing Record 3 of Set 6 | pitimbu
# Processing Record 4 of Set 6 | golden gate
# Processing Record 5 of Set 6 | nizhniy odes
# Processing Record 6 of Set 6 | lorengau
# Processing Record 7 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 6 | waipawa
# Processing Record 9 of Set 6 | cidreira
# Processing Record 10 of Set 6 | alice springs
# Processing Record 11 of Set 6 | paris
# Processing Record 12 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 6 | saryozek
# Processing Record 14 of Set 6 | pontianak
# Processing Record 15 of Set 6 | bengkulu
# Processing Record 16 of Set 6 | iquique
# Processing Record 17 of Set 6 | hunfeld
# Processing Record 18 of Set 6 | bereda
# Processing Record 19 of Set 6 | oum hadjer
# Processing Record 20 of Set 6 | broome
# Processing Record 21 of Set 6 | sao miguel do araguaia
# Processing Record 22 of Set 6 | marawi
# Processing Record 23 of Set 6 | fare
# Processing Record 24 of Set 6 | talara
# Processing Record 25 of Set 6 | amazar
# Processing Record 26 of Set 6 | geresk
# City not found. Skipping...
# Processing Record 27 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 28 of Set 6 | isangel
# Processing Record 29 of Set 6 | cayenne
# Processing Record 30 of Set 6 | sambava
# Processing Record 31 of Set 6 | bastrop
# Processing Record 32 of Set 6 | ailigandi
# Processing Record 33 of Set 6 | san quintin
# Processing Record 34 of Set 6 | dalian
# Processing Record 35 of Set 6 | agustin codazzi
# Processing Record 36 of Set 6 | santa cruz cabralia
# Processing Record 37 of Set 6 | hailar
# Processing Record 38 of Set 6 | lloret de mar
# Processing Record 39 of Set 6 | tuatapere
# Processing Record 40 of Set 6 | sungairaya
# Processing Record 41 of Set 6 | pangai
# Processing Record 42 of Set 6 | humberto de campos
# Processing Record 43 of Set 6 | banjar
# Processing Record 44 of Set 6 | requena
# Processing Record 45 of Set 6 | diego de almagro
# Processing Record 46 of Set 6 | point pedro
# Processing Record 47 of Set 6 | petropavl
# Processing Record 48 of Set 6 | jabinyanah
# Processing Record 49 of Set 6 | torbay
# Processing Record 50 of Set 6 | henties bay
# Processing Record 1 of Set 7 | jodhpur
# Processing Record 2 of Set 7 | atar
# Processing Record 3 of Set 7 | copiapo
# Processing Record 4 of Set 7 | trairi
# Processing Record 5 of Set 7 | huntsville
# Processing Record 6 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 7 | lagoa
# Processing Record 8 of Set 7 | aripuana
# Processing Record 9 of Set 7 | katobu
# Processing Record 10 of Set 7 | dingle
# Processing Record 11 of Set 7 | tamandare
# Processing Record 12 of Set 7 | narsaq
# Processing Record 13 of Set 7 | gwadar
# Processing Record 14 of Set 7 | los llanos de aridane
# Processing Record 15 of Set 7 | ulety
# Processing Record 16 of Set 7 | gizo
# Processing Record 17 of Set 7 | kavaratti
# Processing Record 18 of Set 7 | morden
# Processing Record 19 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 7 | cherdyn
# Processing Record 21 of Set 7 | beringovskiy
# Processing Record 22 of Set 7 | port elizabeth
# Processing Record 23 of Set 7 | victoria
# Processing Record 24 of Set 7 | nhulunbuy
# Processing Record 25 of Set 7 | ihosy
# Processing Record 26 of Set 7 | ginda
# Processing Record 27 of Set 7 | calabasas
# Processing Record 28 of Set 7 | ostrow mazowiecka
# Processing Record 29 of Set 7 | constitucion
# Processing Record 30 of Set 7 | georgetown
# Processing Record 31 of Set 7 | aswan
# Processing Record 32 of Set 7 | acarau
# Processing Record 33 of Set 7 | carnarvon
# Processing Record 34 of Set 7 | boueni
# Processing Record 35 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 7 | isiro
# Processing Record 37 of Set 7 | kashi
# Processing Record 38 of Set 7 | morant bay
# Processing Record 39 of Set 7 | moerai
# Processing Record 40 of Set 7 | mastung
# Processing Record 41 of Set 7 | portland
# Processing Record 42 of Set 7 | tortoli
# Processing Record 43 of Set 7 | homer
# Processing Record 44 of Set 7 | cap malheureux
# Processing Record 45 of Set 7 | nokaneng
# Processing Record 46 of Set 7 | tacuarembo
# Processing Record 47 of Set 7 | nichinan
# Processing Record 48 of Set 7 | pandan
# Processing Record 49 of Set 7 | gasa
# Processing Record 50 of Set 7 | esil
# Processing Record 1 of Set 8 | darhan
# Processing Record 2 of Set 8 | zhmerynka
# Processing Record 3 of Set 8 | afonso bezerra
# Processing Record 4 of Set 8 | westport
# Processing Record 5 of Set 8 | skagastrond
# City not found. Skipping...
# Processing Record 6 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 8 | fortuna
# Processing Record 8 of Set 8 | walvis bay
# Processing Record 9 of Set 8 | tefe
# Processing Record 10 of Set 8 | louis trichardt
# Processing Record 11 of Set 8 | saldanha
# Processing Record 12 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 8 | toora-khem
# Processing Record 14 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 15 of Set 8 | tura
# Processing Record 16 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 17 of Set 8 | inhambane
# Processing Record 18 of Set 8 | maraa
# Processing Record 19 of Set 8 | chagoda
# Processing Record 20 of Set 8 | chojnow
# Processing Record 21 of Set 8 | asfi
# Processing Record 22 of Set 8 | sinnamary
# Processing Record 23 of Set 8 | paamiut
# Processing Record 24 of Set 8 | hovd
# Processing Record 25 of Set 8 | zdunska wola
# Processing Record 26 of Set 8 | leningradskiy
# Processing Record 27 of Set 8 | zhangye
# Processing Record 28 of Set 8 | areosa
# Processing Record 29 of Set 8 | kaseda
# Processing Record 30 of Set 8 | teya
# Processing Record 31 of Set 8 | jasdan
# Processing Record 32 of Set 8 | jacqueville
# Processing Record 33 of Set 8 | montepuez
# Processing Record 34 of Set 8 | calatayud
# Processing Record 35 of Set 8 | preobrazheniye
# Processing Record 36 of Set 8 | ponta delgada
# Processing Record 37 of Set 8 | nanortalik
# Processing Record 38 of Set 8 | afgoye
# City not found. Skipping...
# Processing Record 39 of Set 8 | bathsheba
# Processing Record 40 of Set 8 | boksburg
# Processing Record 41 of Set 8 | burkburnett
# Processing Record 42 of Set 8 | pitea
# Processing Record 43 of Set 8 | loandjili
# Processing Record 44 of Set 8 | paita
# Processing Record 45 of Set 8 | karratha
# Processing Record 46 of Set 8 | manadhoo
# Processing Record 47 of Set 8 | maningrida
# Processing Record 48 of Set 8 | shubarkuduk
# Processing Record 49 of Set 8 | rio gallegos
# Processing Record 50 of Set 8 | vila velha
# Processing Record 1 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 9 | ruyigi
# Processing Record 3 of Set 9 | itumbiara
# Processing Record 4 of Set 9 | lerwick
# Processing Record 5 of Set 9 | santa cruz de tenerife
# Processing Record 6 of Set 9 | loreto
# Processing Record 7 of Set 9 | ostrovnoy
# Processing Record 8 of Set 9 | ngama
# Processing Record 9 of Set 9 | opunake
# Processing Record 10 of Set 9 | yambio
# Processing Record 11 of Set 9 | senador jose porfirio
# Processing Record 12 of Set 9 | paredon
# Processing Record 13 of Set 9 | aksarka
# Processing Record 14 of Set 9 | mizan teferi
# Processing Record 15 of Set 9 | sobolevo
# Processing Record 16 of Set 9 | tautira
# Processing Record 17 of Set 9 | quatre cocos
# Processing Record 18 of Set 9 | aden
# Processing Record 19 of Set 9 | zsombo
# Processing Record 20 of Set 9 | sombrio
# Processing Record 21 of Set 9 | mitu
# Processing Record 22 of Set 9 | hasaki
# Processing Record 23 of Set 9 | guiratinga
# Processing Record 24 of Set 9 | kutum
# Processing Record 25 of Set 9 | akyab
# Processing Record 26 of Set 9 | atambua
# Processing Record 27 of Set 9 | langsa
# Processing Record 28 of Set 9 | ascoli piceno
# Processing Record 29 of Set 9 | olga
# Processing Record 30 of Set 9 | kenai
# Processing Record 31 of Set 9 | bentiu
# Processing Record 32 of Set 9 | gorontalo
# Processing Record 33 of Set 9 | wielun
# Processing Record 34 of Set 9 | yelovo
# Processing Record 35 of Set 9 | santa rosa
# Processing Record 36 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 37 of Set 9 | cabedelo
# Processing Record 38 of Set 9 | almaznyy
# Processing Record 39 of Set 9 | sola
# Processing Record 40 of Set 9 | remontnoye
# Processing Record 41 of Set 9 | biak
# Processing Record 42 of Set 9 | grand gaube
# Processing Record 43 of Set 9 | taoudenni
# Processing Record 44 of Set 9 | maniitsoq
# Processing Record 45 of Set 9 | port moresby
# Processing Record 46 of Set 9 | codrington
# Processing Record 47 of Set 9 | kawalu
# Processing Record 48 of Set 9 | nuevo progreso
# Processing Record 49 of Set 9 | laguna
# Processing Record 50 of Set 9 | omaruru
# Processing Record 1 of Set 10 | kapit
# Processing Record 2 of Set 10 | zafra
# Processing Record 3 of Set 10 | rognan
# Processing Record 4 of Set 10 | lata
# Processing Record 5 of Set 10 | tupik
# Processing Record 6 of Set 10 | okakarara
# Processing Record 7 of Set 10 | hurghada
# Processing Record 8 of Set 10 | jawa
# Processing Record 9 of Set 10 | ushumun
# Processing Record 10 of Set 10 | broken hill
# Processing Record 11 of Set 10 | santa fe
# Processing Record 12 of Set 10 | wairoa
# Processing Record 13 of Set 10 | samarai
# Processing Record 14 of Set 10 | shahrud
# Processing Record 15 of Set 10 | seoul
# Processing Record 16 of Set 10 | altay
# Processing Record 17 of Set 10 | middelburg
# Processing Record 18 of Set 10 | leh
# Processing Record 19 of Set 10 | amapa
# Processing Record 20 of Set 10 | ndjole
# Processing Record 21 of Set 10 | kano
# Processing Record 22 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 10 | jizan
# Processing Record 24 of Set 10 | mandawar
# Processing Record 25 of Set 10 | palmer
# Processing Record 26 of Set 10 | coquimbo
# Processing Record 27 of Set 10 | gbarnga
# Processing Record 28 of Set 10 | mtwara
# Processing Record 29 of Set 10 | la rioja
# Processing Record 30 of Set 10 | adrar
# Processing Record 31 of Set 10 | caravelas
# Processing Record 32 of Set 10 | lavrentiya
# Processing Record 33 of Set 10 | boyolangu
# Processing Record 34 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 10 | almeirim
# Processing Record 36 of Set 10 | lima
# Processing Record 37 of Set 10 | tutoia
# Processing Record 38 of Set 10 | redmond
# Processing Record 39 of Set 10 | asau
# Processing Record 40 of Set 10 | narasapur
# Processing Record 41 of Set 10 | ayan
# Processing Record 42 of Set 10 | kurilsk
# Processing Record 43 of Set 10 | luis correia
# Processing Record 44 of Set 10 | usinsk
# Processing Record 45 of Set 10 | kloulklubed
# Processing Record 46 of Set 10 | am timan
# Processing Record 47 of Set 10 | klaksvik
# Processing Record 48 of Set 10 | san ramon
# Processing Record 49 of Set 10 | barcelos
# Processing Record 50 of Set 10 | college
# Processing Record 1 of Set 11 | constantine
# Processing Record 2 of Set 11 | emerald
# Processing Record 3 of Set 11 | wanaka
# Processing Record 4 of Set 11 | atsiki
# City not found. Skipping...
# Processing Record 5 of Set 11 | riyadh
# Processing Record 6 of Set 11 | general bravo
# Processing Record 7 of Set 11 | zheleznodorozhnyy
# Processing Record 8 of Set 11 | tashara
# Processing Record 9 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 10 of Set 11 | gavle
# Processing Record 11 of Set 11 | yulara
# Processing Record 12 of Set 11 | uarini
# Processing Record 13 of Set 11 | goderich
# Processing Record 14 of Set 11 | faya
# Processing Record 15 of Set 11 | payo
# Processing Record 16 of Set 11 | kendari
# Processing Record 17 of Set 11 | klyuchi
# Processing Record 18 of Set 11 | turkistan
# Processing Record 19 of Set 11 | kiama
# Processing Record 20 of Set 11 | bonavista
# Processing Record 21 of Set 11 | redlands
# Processing Record 22 of Set 11 | nizhniy kuranakh
# Processing Record 23 of Set 11 | boone
# Processing Record 24 of Set 11 | taltal
# Processing Record 25 of Set 11 | shahreza
# Processing Record 26 of Set 11 | sorong
# Processing Record 27 of Set 11 | sidi ali
# Processing Record 28 of Set 11 | linfen
# Processing Record 29 of Set 11 | moroni
# Processing Record 30 of Set 11 | kantang
# Processing Record 31 of Set 11 | mildura
# Processing Record 32 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 33 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 34 of Set 11 | saue
# Processing Record 35 of Set 11 | sioux lookout
# Processing Record 36 of Set 11 | tinskoy
# Processing Record 37 of Set 11 | whitehorse
# Processing Record 38 of Set 11 | tripoli
# Processing Record 39 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 40 of Set 11 | te anau
# Processing Record 41 of Set 11 | tual
# Processing Record 42 of Set 11 | jadu
# Processing Record 43 of Set 11 | pasni
# Processing Record 44 of Set 11 | itoman
# Processing Record 45 of Set 11 | majene
# Processing Record 46 of Set 11 | bjala
# City not found. Skipping...
# Processing Record 47 of Set 11 | sekoma
# Processing Record 48 of Set 11 | luwingu
# Processing Record 49 of Set 11 | guangyuan
# Processing Record 50 of Set 11 | lastoursville
# Processing Record 1 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 2 of Set 12 | pimentel
# Processing Record 3 of Set 12 | san juan
# Processing Record 4 of Set 12 | basoko
# Processing Record 5 of Set 12 | bone
# Processing Record 6 of Set 12 | araouane
# Processing Record 7 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 8 of Set 12 | standerton
# Processing Record 9 of Set 12 | den helder
# Processing Record 10 of Set 12 | kupino
# Processing Record 11 of Set 12 | tallahassee
# Processing Record 12 of Set 12 | la palma
# Processing Record 13 of Set 12 | payakumbuh
# Processing Record 14 of Set 12 | xixiang
# Processing Record 15 of Set 12 | chapais
# Processing Record 16 of Set 12 | sulangan
# Processing Record 17 of Set 12 | kieta
# Processing Record 18 of Set 12 | khilok
# Processing Record 19 of Set 12 | carutapera
# Processing Record 20 of Set 12 | sedelnikovo
# City not found. Skipping...
# Processing Record 21 of Set 12 | saint-cyr-sur-loire
# Processing Record 22 of Set 12 | acapulco
# Processing Record 23 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 24 of Set 12 | flin flon
# Processing Record 25 of Set 12 | promyshlennaya
# Processing Record 26 of Set 12 | tonder
# Processing Record 27 of Set 12 | fomboni
# Processing Record 28 of Set 12 | juneau
# Processing Record 29 of Set 12 | marinette
# Processing Record 30 of Set 12 | tigil
# Processing Record 31 of Set 12 | ayr
# Processing Record 32 of Set 12 | shumikha
# Processing Record 33 of Set 12 | mayo
# Processing Record 34 of Set 12 | shirgaon
# Processing Record 35 of Set 12 | manzhouli
# Processing Record 36 of Set 12 | rawson
# Processing Record 37 of Set 12 | katsiveli
# City not found. Skipping...
# Processing Record 38 of Set 12 | inyonga
# Processing Record 39 of Set 12 | yantal
# Processing Record 40 of Set 12 | kita
# Processing Record 41 of Set 12 | malinovskiy
# Processing Record 42 of Set 12 | port shepstone
# Processing Record 43 of Set 12 | sayyan
# Processing Record 44 of Set 12 | okhotsk
# Processing Record 45 of Set 12 | la asuncion
# Processing Record 46 of Set 12 | ust-shonosha
# Processing Record 47 of Set 12 | acin
# City not found. Skipping...
# Processing Record 48 of Set 12 | jiuquan
# Processing Record 49 of Set 12 | chum phae
# Processing Record 50 of Set 12 | namatanai
# Processing Record 1 of Set 13 | altus
# Processing Record 2 of Set 13 | pavlodar
# Processing Record 3 of Set 13 | lakes entrance
# Processing Record 4 of Set 13 | bakel
# Processing Record 5 of Set 13 | fairbanks
# Processing Record 6 of Set 13 | soyo
# Processing Record 7 of Set 13 | vilyuysk
# Processing Record 8 of Set 13 | merauke
# Processing Record 9 of Set 13 | port-de-paix
# City not found. Skipping...
# Processing Record 10 of Set 13 | oloron-sainte-marie
# Processing Record 11 of Set 13 | telbang
# Processing Record 12 of Set 13 | viedma
# Processing Record 13 of Set 13 | cotonou
# Processing Record 14 of Set 13 | tyukhtet
# Processing Record 15 of Set 13 | tyret pervaya
# Processing Record 16 of Set 13 | dudinka
# Processing Record 17 of Set 13 | bilibino
# Processing Record 18 of Set 13 | bunol
# Processing Record 19 of Set 13 | le vauclin
# Processing Record 20 of Set 13 | coihaique
# Processing Record 21 of Set 13 | verkhnevilyuysk
# Processing Record 22 of Set 13 | bouloupari
# Processing Record 23 of Set 13 | ust-kut
# Processing Record 24 of Set 13 | praia
# Processing Record 25 of Set 13 | abu dhabi
# Processing Record 26 of Set 13 | warrnambool
# Processing Record 27 of Set 13 | gat
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create endpoint URL with each city.
city_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key + "&q=" + "Boston".replace(" ","+")


    # Parse the JSON and retrieve data.
city_weather = requests.get(city_url).json()
city_weather

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
new_column_order = ["column2", "column4", "column1"]
df = df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
new_column_order = ["column2", "column4", "column1"]

# %%
df = df[new_column_order]

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)]

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed', 'Wind Speed',(-50,35))
