# %%
#import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 608

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(5)

    # Create endpoint URL with each city.
    city_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key + "&q=" + city.replace(" ","+")


    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

#Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mangan
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | leningradskiy
# Processing Record 4 of Set 1 | yellowknife
# Processing Record 5 of Set 1 | tevaitoa
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | luderitz
# Processing Record 8 of Set 1 | bandarbeyla
# Processing Record 9 of Set 1 | mayo
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | emirdag
# Processing Record 13 of Set 1 | forio
# Processing Record 14 of Set 1 | aklavik
# Processing Record 15 of Set 1 | quisqueya
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | santiago
# Processing Record 18 of Set 1 | iqaluit
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | rovaniemi
# Processing Record 21 of Set 1 | tateyama
# Processing Record 22 of Set 1 | faya
# Processing Record 23 of Set 1 | wladyslawowo
# Processing Record 24 of Set 1 | springfield
# Processing Record 25 of Set 1 | sitka
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | kruisfontein
# Processing Record 28 of Set 1 | te anau
# Processing Record 29 of Set 1 | half moon bay
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 1 | busselton
# Processing Record 33 of Set 1 | thompson
# Processing Record 34 of Set 1 | husavik
# Processing Record 35 of Set 1 | saint combs
# City not found. Skipping...
# Processing Record 36 of Set 1 | tuatapere
# Processing Record 37 of Set 1 | nenjiang
# Processing Record 38 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 1 | fortuna
# Processing Record 40 of Set 1 | marfino
# Processing Record 41 of Set 1 | kodiak
# Processing Record 42 of Set 1 | mar del plata
# Processing Record 43 of Set 1 | jiddah
# City not found. Skipping...
# Processing Record 44 of Set 1 | kaitangata
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | barrow
# Processing Record 47 of Set 1 | chokurdakh
# Processing Record 48 of Set 1 | bengkulu
# Processing Record 49 of Set 1 | souillac
# Processing Record 50 of Set 1 | castro
# Processing Record 1 of Set 2 | chuy
# Processing Record 2 of Set 2 | puerto ayora
# Processing Record 3 of Set 2 | garmsar
# Processing Record 4 of Set 2 | khatanga
# Processing Record 5 of Set 2 | boddam
# Processing Record 6 of Set 2 | canavieiras
# Processing Record 7 of Set 2 | hamilton
# Processing Record 8 of Set 2 | namibe
# Processing Record 9 of Set 2 | sao joao da barra
# Processing Record 10 of Set 2 | collipulli
# Processing Record 11 of Set 2 | qaanaaq
# Processing Record 12 of Set 2 | dikson
# Processing Record 13 of Set 2 | kapaa
# Processing Record 14 of Set 2 | bud
# Processing Record 15 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 16 of Set 2 | lebu
# Processing Record 17 of Set 2 | kurilsk
# Processing Record 18 of Set 2 | dzhebariki-khaya
# Processing Record 19 of Set 2 | gimli
# Processing Record 20 of Set 2 | san cristobal
# Processing Record 21 of Set 2 | torbay
# Processing Record 22 of Set 2 | isangel
# Processing Record 23 of Set 2 | cap malheureux
# Processing Record 24 of Set 2 | dalvik
# Processing Record 25 of Set 2 | butaritari
# Processing Record 26 of Set 2 | cerritos
# Processing Record 27 of Set 2 | northam
# Processing Record 28 of Set 2 | flinders
# Processing Record 29 of Set 2 | saint-philippe
# Processing Record 30 of Set 2 | hithadhoo
# Processing Record 31 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 2 | finschhafen
# City not found. Skipping...
# Processing Record 33 of Set 2 | tuktoyaktuk
# Processing Record 34 of Set 2 | havoysund
# Processing Record 35 of Set 2 | vaini
# Processing Record 36 of Set 2 | iralaya
# Processing Record 37 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 38 of Set 2 | new norfolk
# Processing Record 39 of Set 2 | kasongo-lunda
# Processing Record 40 of Set 2 | touros
# Processing Record 41 of Set 2 | tiksi
# Processing Record 42 of Set 2 | cabo san lucas
# Processing Record 43 of Set 2 | orange cove
# Processing Record 44 of Set 2 | atchison
# Processing Record 45 of Set 2 | faanui
# Processing Record 46 of Set 2 | olinda
# Processing Record 47 of Set 2 | maceio
# Processing Record 48 of Set 2 | qingan
# City not found. Skipping...
# Processing Record 49 of Set 2 | hasaki
# Processing Record 50 of Set 2 | port augusta
# Processing Record 1 of Set 3 | samarai
# Processing Record 2 of Set 3 | fuxin
# Processing Record 3 of Set 3 | avarua
# Processing Record 4 of Set 3 | sao filipe
# Processing Record 5 of Set 3 | port blair
# Processing Record 6 of Set 3 | ashland
# Processing Record 7 of Set 3 | almeirim
# Processing Record 8 of Set 3 | punta arenas
# Processing Record 9 of Set 3 | mataura
# Processing Record 10 of Set 3 | vila franca do campo
# Processing Record 11 of Set 3 | bintulu
# Processing Record 12 of Set 3 | ankazoabo
# Processing Record 13 of Set 3 | gayny
# Processing Record 14 of Set 3 | geraldton
# Processing Record 15 of Set 3 | komsomolskiy
# Processing Record 16 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 3 | codrington
# Processing Record 18 of Set 3 | atuona
# Processing Record 19 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 20 of Set 3 | pangnirtung
# Processing Record 21 of Set 3 | carnarvon
# Processing Record 22 of Set 3 | banamba
# Processing Record 23 of Set 3 | saldanha
# Processing Record 24 of Set 3 | westport
# Processing Record 25 of Set 3 | belmonte
# Processing Record 26 of Set 3 | kirakira
# Processing Record 27 of Set 3 | sedelnikovo
# City not found. Skipping...
# Processing Record 28 of Set 3 | vao
# Processing Record 29 of Set 3 | port alfred
# Processing Record 30 of Set 3 | manggar
# Processing Record 31 of Set 3 | fort nelson
# Processing Record 32 of Set 3 | tautira
# Processing Record 33 of Set 3 | necochea
# Processing Record 34 of Set 3 | suntar
# Processing Record 35 of Set 3 | ketchikan
# Processing Record 36 of Set 3 | coria
# Processing Record 37 of Set 3 | arraial do cabo
# Processing Record 38 of Set 3 | bathsheba
# Processing Record 39 of Set 3 | teguldet
# Processing Record 40 of Set 3 | doctor arroyo
# Processing Record 41 of Set 3 | kavieng
# Processing Record 42 of Set 3 | ponta do sol
# Processing Record 43 of Set 3 | savelugu
# Processing Record 44 of Set 3 | temaraia
# City not found. Skipping...
# Processing Record 45 of Set 3 | paratinga
# Processing Record 46 of Set 3 | saskylakh
# Processing Record 47 of Set 3 | porto walter
# Processing Record 48 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 3 | beyla
# Processing Record 50 of Set 3 | bairiki
# Processing Record 1 of Set 4 | jamestown
# Processing Record 2 of Set 4 | jumla
# Processing Record 3 of Set 4 | krasnogorsk
# Processing Record 4 of Set 4 | saint-pierre
# Processing Record 5 of Set 4 | saint george
# Processing Record 6 of Set 4 | constitucion
# Processing Record 7 of Set 4 | lompoc
# Processing Record 8 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 4 | victoria
# Processing Record 10 of Set 4 | muzhi
# Processing Record 11 of Set 4 | loa janan
# Processing Record 12 of Set 4 | nago
# Processing Record 13 of Set 4 | manali
# Processing Record 14 of Set 4 | bauchi
# Processing Record 15 of Set 4 | quesnel
# Processing Record 16 of Set 4 | tunduru
# City not found. Skipping...
# Processing Record 17 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 4 | umm lajj
# Processing Record 19 of Set 4 | port elizabeth
# Processing Record 20 of Set 4 | luebo
# Processing Record 21 of Set 4 | santiago del estero
# Processing Record 22 of Set 4 | bluff
# Processing Record 23 of Set 4 | storforshei
# Processing Record 24 of Set 4 | vestmanna
# Processing Record 25 of Set 4 | tochio
# Processing Record 26 of Set 4 | margate
# Processing Record 27 of Set 4 | kargala
# Processing Record 28 of Set 4 | nyurba
# Processing Record 29 of Set 4 | asau
# Processing Record 30 of Set 4 | airai
# Processing Record 31 of Set 4 | lagunas
# Processing Record 32 of Set 4 | pevek
# Processing Record 33 of Set 4 | ganzhou
# Processing Record 34 of Set 4 | santa cruz del sur
# Processing Record 35 of Set 4 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 36 of Set 4 | itarema
# Processing Record 37 of Set 4 | pacific grove
# Processing Record 38 of Set 4 | hofn
# Processing Record 39 of Set 4 | broome
# Processing Record 40 of Set 4 | zhigansk
# Processing Record 41 of Set 4 | bartica
# Processing Record 42 of Set 4 | gulshat
# City not found. Skipping...
# Processing Record 43 of Set 4 | azangaro
# Processing Record 44 of Set 4 | dobric
# Processing Record 45 of Set 4 | kashi
# Processing Record 46 of Set 4 | biak
# Processing Record 47 of Set 4 | magadan
# Processing Record 48 of Set 4 | pitimbu
# Processing Record 49 of Set 4 | oranjestad
# Processing Record 50 of Set 4 | grand-santi
# Processing Record 1 of Set 5 | zaozerne
# Processing Record 2 of Set 5 | oranjemund
# Processing Record 3 of Set 5 | vila velha
# Processing Record 4 of Set 5 | east london
# Processing Record 5 of Set 5 | ilulissat
# Processing Record 6 of Set 5 | gizo
# Processing Record 7 of Set 5 | regina
# Processing Record 8 of Set 5 | ribeira grande
# Processing Record 9 of Set 5 | mahebourg
# Processing Record 10 of Set 5 | choix
# Processing Record 11 of Set 5 | griffith
# Processing Record 12 of Set 5 | coquimbo
# Processing Record 13 of Set 5 | kissidougou
# Processing Record 14 of Set 5 | georgetown
# Processing Record 15 of Set 5 | carranglan
# Processing Record 16 of Set 5 | havre-saint-pierre
# Processing Record 17 of Set 5 | thinadhoo
# Processing Record 18 of Set 5 | mankera
# Processing Record 19 of Set 5 | egvekinot
# Processing Record 20 of Set 5 | lircay
# Processing Record 21 of Set 5 | fort saint james
# Processing Record 22 of Set 5 | chapais
# Processing Record 23 of Set 5 | nantucket
# Processing Record 24 of Set 5 | bossangoa
# Processing Record 25 of Set 5 | sabha
# Processing Record 26 of Set 5 | paita
# Processing Record 27 of Set 5 | porto novo
# Processing Record 28 of Set 5 | forest
# Processing Record 29 of Set 5 | tessalit
# Processing Record 30 of Set 5 | baghdad
# Processing Record 31 of Set 5 | ahipara
# Processing Record 32 of Set 5 | aykhal
# Processing Record 33 of Set 5 | saurimo
# Processing Record 34 of Set 5 | usinsk
# Processing Record 35 of Set 5 | odweyne
# Processing Record 36 of Set 5 | singaraja
# Processing Record 37 of Set 5 | nanortalik
# Processing Record 38 of Set 5 | la rioja
# Processing Record 39 of Set 5 | dakar
# Processing Record 40 of Set 5 | storslett
# Processing Record 41 of Set 5 | lewisporte
# Processing Record 42 of Set 5 | mafeteng
# Processing Record 43 of Set 5 | oeiras do para
# Processing Record 44 of Set 5 | yulara
# Processing Record 45 of Set 5 | jinchang
# Processing Record 46 of Set 5 | caxias
# Processing Record 47 of Set 5 | atyrau
# Processing Record 48 of Set 5 | acapulco
# Processing Record 49 of Set 5 | port keats
# Processing Record 50 of Set 5 | severo-kurilsk
# Processing Record 1 of Set 6 | bambous virieux
# Processing Record 2 of Set 6 | jutai
# Processing Record 3 of Set 6 | manaure
# Processing Record 4 of Set 6 | kahului
# Processing Record 5 of Set 6 | arman
# Processing Record 6 of Set 6 | tsiroanomandidy
# Processing Record 7 of Set 6 | lusambo
# Processing Record 8 of Set 6 | fairbanks
# Processing Record 9 of Set 6 | srednekolymsk
# Processing Record 10 of Set 6 | nelson bay
# Processing Record 11 of Set 6 | vostok
# Processing Record 12 of Set 6 | los llanos de aridane
# Processing Record 13 of Set 6 | esperance
# Processing Record 14 of Set 6 | pakwach
# City not found. Skipping...
# Processing Record 15 of Set 6 | urengoy
# Processing Record 16 of Set 6 | coos bay
# Processing Record 17 of Set 6 | san patricio
# Processing Record 18 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 6 | naze
# Processing Record 20 of Set 6 | kupang
# Processing Record 21 of Set 6 | rawson
# Processing Record 22 of Set 6 | ledyard
# Processing Record 23 of Set 6 | novoilinsk
# Processing Record 24 of Set 6 | nishihara
# Processing Record 25 of Set 6 | hualmay
# Processing Record 26 of Set 6 | careiro da varzea
# Processing Record 27 of Set 6 | quang ngai
# Processing Record 28 of Set 6 | bentiu
# Processing Record 29 of Set 6 | pemberton
# Processing Record 30 of Set 6 | caracuaro
# Processing Record 31 of Set 6 | maues
# Processing Record 32 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 6 | lagoa
# Processing Record 34 of Set 6 | gat
# Processing Record 35 of Set 6 | clyde river
# Processing Record 36 of Set 6 | hammond
# Processing Record 37 of Set 6 | stoyba
# City not found. Skipping...
# Processing Record 38 of Set 6 | mecca
# Processing Record 39 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 40 of Set 6 | hanmer springs
# Processing Record 41 of Set 6 | namatanai
# Processing Record 42 of Set 6 | wonthaggi
# Processing Record 43 of Set 6 | ambalavao
# Processing Record 44 of Set 6 | palmer
# Processing Record 45 of Set 6 | panzhihua
# Processing Record 46 of Set 6 | nikolskoye
# Processing Record 47 of Set 6 | hervey bay
# Processing Record 48 of Set 6 | severo-yeniseyskiy
# Processing Record 49 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 50 of Set 6 | khorinsk
# Processing Record 1 of Set 7 | lavrentiya
# Processing Record 2 of Set 7 | reitz
# Processing Record 3 of Set 7 | dubenskiy
# City not found. Skipping...
# Processing Record 4 of Set 7 | hinton
# Processing Record 5 of Set 7 | grindavik
# Processing Record 6 of Set 7 | yar-sale
# Processing Record 7 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 7 | puerto ayacucho
# Processing Record 9 of Set 7 | dhidhdhoo
# Processing Record 10 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 11 of Set 7 | pemangkat
# Processing Record 12 of Set 7 | seybaplaya
# Processing Record 13 of Set 7 | berlevag
# Processing Record 14 of Set 7 | isiolo
# Processing Record 15 of Set 7 | tirau
# Processing Record 16 of Set 7 | tarrafal
# Processing Record 17 of Set 7 | longyearbyen
# Processing Record 18 of Set 7 | cocoa beach
# Processing Record 19 of Set 7 | tasiilaq
# Processing Record 20 of Set 7 | dharangaon
# Processing Record 21 of Set 7 | doha
# Processing Record 22 of Set 7 | port lincoln
# Processing Record 23 of Set 7 | nakamura
# Processing Record 24 of Set 7 | cayenne
# Processing Record 25 of Set 7 | carutapera
# Processing Record 26 of Set 7 | taoudenni
# Processing Record 27 of Set 7 | dinard
# Processing Record 28 of Set 7 | zemio
# Processing Record 29 of Set 7 | norman wells
# Processing Record 30 of Set 7 | dicabisagan
# Processing Record 31 of Set 7 | galle
# Processing Record 32 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 33 of Set 7 | sinop
# Processing Record 34 of Set 7 | ambilobe
# Processing Record 35 of Set 7 | padang
# Processing Record 36 of Set 7 | bria
# Processing Record 37 of Set 7 | saint-joseph
# Processing Record 38 of Set 7 | tual
# Processing Record 39 of Set 7 | bethel
# Processing Record 40 of Set 7 | mamallapuram
# Processing Record 41 of Set 7 | la ronge
# Processing Record 42 of Set 7 | mahanoro
# Processing Record 43 of Set 7 | raudeberg
# Processing Record 44 of Set 7 | upernavik
# Processing Record 45 of Set 7 | luau
# Processing Record 46 of Set 7 | pochutla
# Processing Record 47 of Set 7 | jinchengjiang
# City not found. Skipping...
# Processing Record 48 of Set 7 | lorengau
# Processing Record 49 of Set 7 | talnakh
# Processing Record 50 of Set 7 | coihaique
# Processing Record 1 of Set 8 | tashara
# Processing Record 2 of Set 8 | sinnamary
# Processing Record 3 of Set 8 | crab hill
# City not found. Skipping...
# Processing Record 4 of Set 8 | kinkala
# Processing Record 5 of Set 8 | edd
# Processing Record 6 of Set 8 | alice springs
# Processing Record 7 of Set 8 | aitape
# Processing Record 8 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 8 | provideniya
# Processing Record 10 of Set 8 | vaitape
# Processing Record 11 of Set 8 | amuntai
# Processing Record 12 of Set 8 | penzance
# Processing Record 13 of Set 8 | puerto escondido
# Processing Record 14 of Set 8 | caravelas
# Processing Record 15 of Set 8 | bocas del toro
# Processing Record 16 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 8 | velagici
# Processing Record 18 of Set 8 | mount gambier
# Processing Record 19 of Set 8 | kawalu
# Processing Record 20 of Set 8 | presidencia roque saenz pena
# Processing Record 21 of Set 8 | caborca
# Processing Record 22 of Set 8 | ulladulla
# Processing Record 23 of Set 8 | pangkalanbuun
# Processing Record 24 of Set 8 | meulaboh
# Processing Record 25 of Set 8 | quzhou
# Processing Record 26 of Set 8 | sogdiondon
# City not found. Skipping...
# Processing Record 27 of Set 8 | karangampel
# Processing Record 28 of Set 8 | tinjah
# City not found. Skipping...
# Processing Record 29 of Set 8 | port hardy
# Processing Record 30 of Set 8 | vetralla
# Processing Record 31 of Set 8 | raga
# Processing Record 32 of Set 8 | phalaborwa
# Processing Record 33 of Set 8 | alibag
# Processing Record 34 of Set 8 | jieshi
# Processing Record 35 of Set 8 | boueni
# Processing Record 36 of Set 8 | sept-iles
# Processing Record 37 of Set 8 | kamaishi
# Processing Record 38 of Set 8 | sampit
# Processing Record 39 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 8 | kikwit
# Processing Record 41 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 42 of Set 8 | dubbo
# Processing Record 43 of Set 8 | dinklage
# Processing Record 44 of Set 8 | ocampo
# Processing Record 45 of Set 8 | takoradi
# Processing Record 46 of Set 8 | ostrovnoy
# Processing Record 47 of Set 8 | antalaha
# Processing Record 48 of Set 8 | el alto
# Processing Record 49 of Set 8 | svetlyy
# Processing Record 50 of Set 8 | viedma
# Processing Record 1 of Set 9 | rocha
# Processing Record 2 of Set 9 | umm bab
# Processing Record 3 of Set 9 | chapaevsk
# Processing Record 4 of Set 9 | west wendover
# Processing Record 5 of Set 9 | ancud
# Processing Record 6 of Set 9 | one hundred mile house
# City not found. Skipping...
# Processing Record 7 of Set 9 | mumford
# Processing Record 8 of Set 9 | cidreira
# Processing Record 9 of Set 9 | andra
# Processing Record 10 of Set 9 | playas
# Processing Record 11 of Set 9 | algarrobo
# Processing Record 12 of Set 9 | virden
# Processing Record 13 of Set 9 | sungaipenuh
# Processing Record 14 of Set 9 | macaboboni
# City not found. Skipping...
# Processing Record 15 of Set 9 | kirkuk
# Processing Record 16 of Set 9 | praia
# Processing Record 17 of Set 9 | urucara
# Processing Record 18 of Set 9 | kazuno
# Processing Record 19 of Set 9 | karratha
# Processing Record 20 of Set 9 | honiara
# Processing Record 21 of Set 9 | ramos arizpe
# Processing Record 22 of Set 9 | vonnu
# City not found. Skipping...
# Processing Record 23 of Set 9 | alot
# Processing Record 24 of Set 9 | cherskiy
# Processing Record 25 of Set 9 | krasnovishersk
# Processing Record 26 of Set 9 | muros
# Processing Record 27 of Set 9 | pangody
# Processing Record 28 of Set 9 | ust-maya
# Processing Record 29 of Set 9 | pisco
# Processing Record 30 of Set 9 | hajnowka
# Processing Record 31 of Set 9 | twentynine palms
# Processing Record 32 of Set 9 | kroya
# Processing Record 33 of Set 9 | bundaberg
# Processing Record 34 of Set 9 | tura
# Processing Record 35 of Set 9 | luwuk
# Processing Record 36 of Set 9 | launceston
# Processing Record 37 of Set 9 | iquique
# Processing Record 38 of Set 9 | bilma
# Processing Record 39 of Set 9 | hutchinson
# Processing Record 40 of Set 9 | burica
# City not found. Skipping...
# Processing Record 41 of Set 9 | mandapam
# Processing Record 42 of Set 9 | diamantino
# Processing Record 43 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 9 | lavumisa
# Processing Record 45 of Set 9 | grand forks
# Processing Record 46 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 9 | tandil
# Processing Record 48 of Set 9 | luanda
# Processing Record 49 of Set 9 | ewa beach
# Processing Record 50 of Set 9 | dunedin
# Processing Record 1 of Set 10 | verkhoyansk
# Processing Record 2 of Set 10 | sioux lookout
# Processing Record 3 of Set 10 | sambava
# Processing Record 4 of Set 10 | jining
# Processing Record 5 of Set 10 | alta floresta
# Processing Record 6 of Set 10 | chaman
# Processing Record 7 of Set 10 | sorong
# Processing Record 8 of Set 10 | sola
# Processing Record 9 of Set 10 | abrau-dyurso
# Processing Record 10 of Set 10 | kresttsy
# Processing Record 11 of Set 10 | hatillo
# Processing Record 12 of Set 10 | eureka
# Processing Record 13 of Set 10 | nemuro
# Processing Record 14 of Set 10 | yaan
# Processing Record 15 of Set 10 | ixtapa
# Processing Record 16 of Set 10 | haines junction
# Processing Record 17 of Set 10 | villa de cura
# Processing Record 18 of Set 10 | aksarka
# Processing Record 19 of Set 10 | bolonchen
# City not found. Skipping...
# Processing Record 20 of Set 10 | salalah
# Processing Record 21 of Set 10 | ternate
# Processing Record 22 of Set 10 | kieta
# Processing Record 23 of Set 10 | rio grande
# Processing Record 24 of Set 10 | perehonivka
# Processing Record 25 of Set 10 | guerrero negro
# Processing Record 26 of Set 10 | klaksvik
# Processing Record 27 of Set 10 | meiktila
# Processing Record 28 of Set 10 | tobermory
# Processing Record 29 of Set 10 | mirandopolis
# Processing Record 30 of Set 10 | vanavara
# Processing Record 31 of Set 10 | svetlogorsk
# Processing Record 32 of Set 10 | kyzyl-suu
# Processing Record 33 of Set 10 | vestmannaeyjar
# Processing Record 34 of Set 10 | udachnyy
# Processing Record 35 of Set 10 | okakarara
# Processing Record 36 of Set 10 | warrnambool
# Processing Record 37 of Set 10 | karoi
# Processing Record 38 of Set 10 | sawtell
# Processing Record 39 of Set 10 | morondava
# Processing Record 40 of Set 10 | deputatskiy
# Processing Record 41 of Set 10 | corn island
# Processing Record 42 of Set 10 | craig
# Processing Record 43 of Set 10 | ouesso
# Processing Record 44 of Set 10 | excelsior springs
# Processing Record 45 of Set 10 | arantangi
# Processing Record 46 of Set 10 | kefamenanu
# Processing Record 47 of Set 10 | laguna
# Processing Record 48 of Set 10 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 10 | gravelbourg
# Processing Record 50 of Set 10 | nchelenge
# Processing Record 1 of Set 11 | katsuura
# Processing Record 2 of Set 11 | palkino
# Processing Record 3 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 11 | ust-omchug
# Processing Record 5 of Set 11 | belyy yar
# Processing Record 6 of Set 11 | urumqi
# Processing Record 7 of Set 11 | san andres
# Processing Record 8 of Set 11 | longkou
# Processing Record 9 of Set 11 | yilan
# Processing Record 10 of Set 11 | kalat
# Processing Record 11 of Set 11 | krasnoselkup
# Processing Record 12 of Set 11 | nyandoma
# Processing Record 13 of Set 11 | saint anthony
# Processing Record 14 of Set 11 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 15 of Set 11 | mandali
# Processing Record 16 of Set 11 | kembolcha
# Processing Record 17 of Set 11 | vrangel
# Processing Record 18 of Set 11 | paoua
# Processing Record 19 of Set 11 | san quintin
# Processing Record 20 of Set 11 | hailar
# Processing Record 21 of Set 11 | socorro
# Processing Record 22 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 23 of Set 11 | najran
# Processing Record 24 of Set 11 | zapolyarnyy
# Processing Record 25 of Set 11 | sao felix do xingu
# Processing Record 26 of Set 11 | sur
# Processing Record 27 of Set 11 | henties bay
# Processing Record 28 of Set 11 | boyuibe
# Processing Record 29 of Set 11 | prince rupert
# Processing Record 30 of Set 11 | jacksonville beach
# Processing Record 31 of Set 11 | aleksandrov gay
# Processing Record 32 of Set 11 | pemba
# Processing Record 33 of Set 11 | kobyzhcha
# Processing Record 34 of Set 11 | kangaatsiaq
# Processing Record 35 of Set 11 | wattegama
# Processing Record 36 of Set 11 | urucui
# Processing Record 37 of Set 11 | jiblah
# Processing Record 38 of Set 11 | gobabis
# Processing Record 39 of Set 11 | montemor-o-novo
# Processing Record 40 of Set 11 | toungoo
# City not found. Skipping...
# Processing Record 41 of Set 11 | tomohon
# Processing Record 42 of Set 11 | dalbandin
# Processing Record 43 of Set 11 | oistins
# Processing Record 44 of Set 11 | santa comba
# Processing Record 45 of Set 11 | libreville
# Processing Record 46 of Set 11 | hearst
# Processing Record 47 of Set 11 | tartus
# Processing Record 48 of Set 11 | makat
# Processing Record 49 of Set 11 | fuyu
# Processing Record 50 of Set 11 | byron bay
# Processing Record 1 of Set 12 | castlebar
# Processing Record 2 of Set 12 | maningrida
# Processing Record 3 of Set 12 | northport
# Processing Record 4 of Set 12 | powell river
# Processing Record 5 of Set 12 | port-cartier
# Processing Record 6 of Set 12 | bossembele
# City not found. Skipping...
# Processing Record 7 of Set 12 | hirara
# Processing Record 8 of Set 12 | key west
# Processing Record 9 of Set 12 | kyshtovka
# Processing Record 10 of Set 12 | ellsworth
# Processing Record 11 of Set 12 | rafaela
# Processing Record 12 of Set 12 | bowen
# Processing Record 13 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 12 | sao gabriel da cachoeira
# Processing Record 15 of Set 12 | kisangani
# Processing Record 16 of Set 12 | shache
# Processing Record 17 of Set 12 | nome
# Processing Record 18 of Set 12 | mwinilunga
# Processing Record 19 of Set 12 | novopavlovka
# Processing Record 20 of Set 12 | ionesti
# Processing Record 21 of Set 12 | izazi
# Processing Record 22 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 12 | bilibino
# Processing Record 24 of Set 12 | charagua
# Processing Record 25 of Set 12 | turukhansk
# Processing Record 26 of Set 12 | high level
# Processing Record 27 of Set 12 | rabo de peixe
# Processing Record 28 of Set 12 | alofi
# Processing Record 29 of Set 12 | malwan
# City not found. Skipping...
# Processing Record 30 of Set 12 | hurup
# Processing Record 31 of Set 12 | solenzo
# Processing Record 32 of Set 12 | roma
# Processing Record 33 of Set 12 | umm jarr
# City not found. Skipping...
# Processing Record 34 of Set 12 | monroe
# Processing Record 35 of Set 12 | lianran
# Processing Record 36 of Set 12 | acarau
# Processing Record 37 of Set 12 | ponta delgada
# Processing Record 38 of Set 12 | villa guerrero
# Processing Record 39 of Set 12 | bom jardim
# Processing Record 40 of Set 12 | malaya vishera
# Processing Record 41 of Set 12 | grootfontein
# Processing Record 42 of Set 12 | thunder bay
# Processing Record 43 of Set 12 | botad
# Processing Record 44 of Set 12 | ahuimanu
# Processing Record 45 of Set 12 | gotsu
# Processing Record 46 of Set 12 | makakilo city
# Processing Record 47 of Set 12 | fukue
# Processing Record 48 of Set 12 | kiama
# Processing Record 49 of Set 12 | hambantota
# Processing Record 50 of Set 12 | korla
# Processing Record 1 of Set 13 | eydhafushi
# Processing Record 2 of Set 13 | petauke
# Processing Record 3 of Set 13 | telixtlahuaca
# City not found. Skipping...
# Processing Record 4 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 5 of Set 13 | kavaratti
# Processing Record 6 of Set 13 | pontianak
# Processing Record 7 of Set 13 | flin flon
# Processing Record 8 of Set 13 | blomberg
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create endpoint URL with each city.
city_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key + "&q=" + "Boston".replace(" ","+")


    # Parse the JSON and retrieve data.
city_weather = requests.get(city_url).json()
city_weather
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 21.54,
#   'feels_like': 16,
#   'temp_min': 16.52,
#   'temp_max': 25.16,
#   'pressure': 1025,
#   'humidity': 56},
#  'visibility': 10000,
#  'wind': {'speed': 4, 'deg': 290, 'gust': 8.01},
#  'clouds': {'all': 20},
#  'dt': 1643332244,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1643284958,
#   'sunset': 1643320268},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
new_column_order = ["column2", "column4", "column1"]
df = df[new_column_order]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3968/4144671674.py in <module>
#       3 city_data_df.head(10)
#       4 new_column_order = ["column2", "column4", "column1"]
# ----> 5 df = df[new_column_order]
#
# NameError: name 'df' is not defined

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# %%
new_column_order = ["column2", "column4", "column1"]

# %%
df = df[new_column_order]
